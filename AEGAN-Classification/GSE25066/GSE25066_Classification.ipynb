# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('GSE25066_merge.csv')
y = np.array(data.pop("group"))
# y = np.expand_dims(y, axis=1)

# %%
origin_X = np.array(data)

# %%
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from tqdm import tqdm

# 创建一个随机森林分类器，假设要使用100个决策树
rf_classifier = RandomForestClassifier(n_estimators=100)

# 定义k-fold交叉验证，将数据分成10个子集
k_fold = KFold(n_splits=3, random_state=42, shuffle=True)

# 定义变量来存储每次交叉验证的得分
scores = []

# 对于每个训练集和验证集的子集，分别进行训练和预测
for train_indices, test_indices in tqdm(k_fold.split(X)):
    X_train, X_test = origin_X[train_indices], origin_X[test_indices]
    y_train, y_test = y[train_indices], y[test_indices]
    
    # 训练分类器
    rf_classifier.fit(X_train, y_train)
    
    # 在验证集上进行预测
    score = rf_classifier.score(X_test, y_test)
    
    # 将得分添加到得分列表中
    scores.append(score)

# 打印每次交叉验证的得分以及平均得分
print("Cross-validation scores: {}".format(scores))
print("Average score: {}".format(sum(scores) / len(scores)))

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split


# 计算每个指标的平均值

def train(X, y, n_splits=8, test=0.2, random_state=42, n_estimators=200):
    # 创建一个随机森林分类器
    rf_classifier = RandomForestClassifier(random_state=random_state, n_estimators=n_estimators)
    
    # 设置K-fold交叉验证策略
    cv = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    X_len = len(X)
    t = int((1-test)*X_len)
    print(f'n_splits:{n_splits},test_data:{test},random_state:{random_state},n_estimators:{n_estimators}')
    num_samples = X.shape[0]

    # 生成随机排列索引
    np.random.seed(random_state)
    # 划分训练集和测试集
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test, stratify=y, random_state=random_state)
    # 定义要计算的分类指标
    scoring = {
        'Accuracy': 'accuracy',
        'Recall': 'recall',
        'Precision': 'precision',
        'F1': 'f1',
        'Auc': 'roc_auc'
    }
    score_train = {}
    score_test = {}
    print(X.shape,X_train.shape,X_test.shape)
    for metric_name, metric_func in scoring.items():
        metric_scores = cross_val_score(rf_classifier, X_train, y_train, cv=cv, scoring=metric_func, n_jobs=-1)
        avg_metric_score = metric_scores.mean()
        score_train[metric_name] = round(avg_metric_score, 3)
        print(f'validation: {metric_name}: {avg_metric_score:.3f}')
    # 选择最佳模型参数设置
    best_model_params = rf_classifier.get_params() 
    # 使用最佳参数设置重新训练模型
    best_model = RandomForestClassifier(**best_model_params)
    best_model.fit(X_train, y_train)
    y_pred = best_model.predict(X_test)
    score_test['Accuracy'] = round(accuracy_score(y_test, y_pred),3)
    score_test['Recall'] = round(recall_score(y_test, y_pred),3 )
    score_test['Precision'] = round(precision_score(y_test, y_pred),3)
    score_test['F1'] = round(f1_score(y_test, y_pred), 3)
    score_test['Auc'] = round(roc_auc_score(y_test, y_pred), 3)
    print('***********test*************')
    print(score_test)
    # for metric_name, metric_func in scoring.items():
    #     metric_scores = cross_val_score(rf_classifier, X_test, y_test, scoring=metric_func, n_jobs=-1)
    #     avg_metric_score = metric_scores.mean()
    #     score_test[metric_name] = round(avg_metric_score, 3)
    #     print(f'test: {metric_name}: {avg_metric_score:.3f}')
    return score_train, score_test

# %% [markdown]
# # Origin_score

# %%
_,origin_score = train(origin_X, y, 8, test=0.1, n_estimators=100)
origin_score

# %%
from sklearn.datasets import make_classification
from collections import Counter
# 获取gan生成的数据
gan_df_X = pd.read_csv('gan_GSE25066.csv')
gan_df_y = np.array(gan_df_X.pop("group"))
print(f'数据集中各类别样本的数量：{Counter(y)}')
print(f'生成对抗网络生成之后各类别样本的数量：{Counter(gan_df_y)}')

# %%
gan_X  = np.array(gan_df_X)
gan_X, gan_df_y

# %% [markdown]
# # Gan_score

# %%
_, gan_score = train(gan_X, gan_df_y, 8, test=0.1, n_estimators=100, random_state=42)
gan_score

# %% [markdown]
# # 读取pathways特征

# %%
ptways = pd.read_csv('GSE25066_Pathways.csv')
ptways_y = np.array(ptways.pop("group"))
ptways_X = np.array(ptways)

# %%
Counter(ptways_y)

# %%
train(ptways_X, ptways_y, 8)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# 创建一个递归特征消除器
estimator = LogisticRegression()
selector = RFE(estimator, n_features_to_select=245, step=1)

# 使用选择器对特征进行选择
X_selected = selector.fit_transform(ptways_X, ptways_y)

# %%
# from sklearn.feature_selection import VarianceThreshold

# # 创建一个方差阈值特征选择器
# selector = VarianceThreshold(threshold=0.070)

# # 使用选择器对特征进行选择
# X_selected = selector.fit_transform(ptways_X)

# %%
X_selected.shape

# %% [markdown]
# # Gan_pathifier_score

# %%
_, gan_pathifier_score = train(X_selected, ptways_y, n_splits=8, test=0.1, n_estimators=100, random_state=42)

# %%
origin_score,gan_score, gan_pathifier_score

# %%
# 绘制性能指标对比图像
import matplotlib.pyplot as plt
X = ['Accuracy','Recall', 'Precision', 'F1', 'AUC']
X_labels = ['ORIGIN_RF','GAN_RF', 'GAN_PATHIFIER_RF' ]
ORIGIN_RF_score_bar = [origin_score['Accuracy'], origin_score['Recall'], origin_score['Precision'],origin_score['F1'],origin_score['Auc']]
GAN_RF_score_bar = [gan_score['Accuracy'], gan_score['Recall'], gan_score['Precision'],gan_score['F1'],gan_score['Auc']]
GAN_PATHIFIER_RF_score_bar = [gan_pathifier_score['Accuracy'], gan_pathifier_score['Recall'], gan_pathifier_score['Precision'],gan_pathifier_score['F1'],gan_pathifier_score['Auc']]

def plot_preference(X, X_labels, origin_score, gan_score, gan_pathifier_score, save_fig='GSE25066_Classification.png', title='GSE25066 Classification'):
    plt.figure(figsize=(13,8))
    # 设置柱状图的宽度
    bar_width = 0.25
    # 生成X轴上的位置
    index = np.arange(len(X))
    plt.bar(index, ORIGIN_RF_score_bar, bar_width, label=X_labels[0])
    
    plt.bar(index + bar_width, GAN_RF_score_bar, bar_width, label=X_labels[1])
    
    plt.bar(index + 2 * bar_width, GAN_PATHIFIER_RF_score_bar, bar_width, label=X_labels[2])
    
    # 添加标题和标签
    plt.title(title)
    plt.xlabel('Performance')
    plt.ylabel('Score(%)')
    
    # 添加方法名称到图例中
    plt.legend(fontsize=7, loc='upper left')
    
    # 调整X轴刻度标签
    plt.xticks(index + 1.5 * bar_width, X)
    for i, v in enumerate(ORIGIN_RF_score_bar):
        plt.text(i, v, str(v), ha='center', va='bottom')
    for i, v in enumerate(GAN_RF_score_bar):
        plt.text(i + bar_width, v, str(v), ha='center', va='bottom')
    for i, v in enumerate(GAN_PATHIFIER_RF_score_bar):
        plt.text(i + 2 * bar_width, v, str(v), ha='center', va='bottom')
    plt.savefig(save_fig)
    # 展示图形
    plt.show()

# %%
plot_preference(X=X, 
                X_labels=X_labels,
                origin_score=origin_score,
                gan_score=gan_score,
                gan_pathifier_score=gan_pathifier_score,
                title='GSE25066 Classification'
               )

# %% [markdown]
# # 使用其他分类器对比

# %%
from sklearn.svm import SVC

def train_model(X, y, n_splits=8, test=0.2, random_state=42, n_estimators=200, model='rf'):
    # 创建一个随机森林分类器
    rf_classifier = RandomForestClassifier(random_state=random_state, n_estimators=n_estimators)
    
    # 设置K-fold交叉验证策略
    cv = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    X_len = len(X)
    t = int((1-test)*X_len)
    print(f'n_splits:{n_splits},test_data:{test},random_state:{random_state},n_estimators:{n_estimators}')
    num_samples = X.shape[0]

    # 生成随机排列索引
    np.random.seed(random_state)
    # 划分训练集和测试集
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test, stratify=y, random_state=random_state)
    # 定义要计算的分类指标
    scoring = {
        'Accuracy': 'accuracy',
        'Recall': 'recall',
        'Precision': 'precision',
        'F1': 'f1',
        'Auc': 'roc_auc'
    }
    score_train = {}
    score_test = {}
    print(X.shape,X_train.shape,X_test.shape)
    for metric_name, metric_func in scoring.items():
        metric_scores = cross_val_score(rf_classifier, X_train, y_train, cv=cv, scoring=metric_func, n_jobs=-1)
        avg_metric_score = metric_scores.mean()
        score_train[metric_name] = round(avg_metric_score, 3)
        print(f'validation: {metric_name}: {avg_metric_score:.3f}')
    # 选择最佳模型参数设置
    best_model_params = rf_classifier.get_params() 
    # 使用最佳参数设置重新训练模型
    best_model = RandomForestClassifier(**best_model_params)
    best_model.fit(X_train, y_train)
    y_pred = best_model.predict(X_test)
    score_test['Accuracy'] = round(accuracy_score(y_test, y_pred),3)
    score_test['Recall'] = round(recall_score(y_test, y_pred),3 )
    score_test['Precision'] = round(precision_score(y_test, y_pred),3)
    score_test['F1'] = round(f1_score(y_test, y_pred), 3)
    score_test['Auc'] = round(roc_auc_score(y_test, y_pred), 3)
    print('***********test*************')
    print(score_test)
    # for metric_name, metric_func in scoring.items():
    #     metric_scores = cross_val_score(rf_classifier, X_test, y_test, scoring=metric_func, n_jobs=-1)
    #     avg_metric_score = metric_scores.mean()
    #     score_test[metric_name] = round(avg_metric_score, 3)
    #     print(f'test: {metric_name}: {avg_metric_score:.3f}')
    return score_train, score_test
def select_model(model):
    models = {
        "rf": RandomForestClassifier(),
        "svm": SVC()
    }

# %% [markdown]
# # 使用pycaret训练

# %% [markdown]
# ## 读取原始数据

# %%
import pandas as pd
import numpy as np

# %%
train_size = 0.9
fold = 8

# %%
origin_data = pd.read_csv('GSE25066_merge.csv')

# %%
from pycaret.classification import ClassificationExperiment
s = ClassificationExperiment()
s.set_config('seed', 42)
s.setup(origin_data,
        target = 'group', 
        session_id = 42, 
        train_size=train_size,
        fold_strategy='kfold',
        fold=fold,
       )
# Out:
# <style type="text/css">
# #T_9cc5e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9cc5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cc5e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9cc5e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cc5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9cc5e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9cc5e_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9cc5e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9cc5e_row1_col1" class="data row1 col1" >group</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9cc5e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9cc5e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9cc5e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9cc5e_row3_col1" class="data row3 col1" >(488, 13237)</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9cc5e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9cc5e_row4_col1" class="data row4 col1" >(488, 13237)</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9cc5e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9cc5e_row5_col1" class="data row5 col1" >(439, 13237)</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9cc5e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9cc5e_row6_col1" class="data row6 col1" >(49, 13237)</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9cc5e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9cc5e_row7_col1" class="data row7 col1" >13236</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9cc5e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_9cc5e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9cc5e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_9cc5e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9cc5e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_9cc5e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9cc5e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_9cc5e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9cc5e_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_9cc5e_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9cc5e_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_9cc5e_row13_col1" class="data row13 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9cc5e_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_9cc5e_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9cc5e_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_9cc5e_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9cc5e_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_9cc5e_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9cc5e_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_9cc5e_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9cc5e_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_9cc5e_row18_col1" class="data row18 col1" >78de</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.compare_models()
# Out:
# <style type="text/css">
# #T_e1a90 th {
#   text-align: left;
# }
# #T_e1a90_row0_col0, #T_e1a90_row0_col2, #T_e1a90_row0_col3, #T_e1a90_row0_col4, #T_e1a90_row1_col0, #T_e1a90_row1_col1, #T_e1a90_row1_col3, #T_e1a90_row1_col4, #T_e1a90_row1_col5, #T_e1a90_row1_col6, #T_e1a90_row1_col7, #T_e1a90_row2_col0, #T_e1a90_row2_col1, #T_e1a90_row2_col2, #T_e1a90_row2_col3, #T_e1a90_row2_col4, #T_e1a90_row2_col5, #T_e1a90_row2_col6, #T_e1a90_row2_col7, #T_e1a90_row3_col0, #T_e1a90_row3_col1, #T_e1a90_row3_col2, #T_e1a90_row3_col3, #T_e1a90_row3_col4, #T_e1a90_row3_col5, #T_e1a90_row3_col6, #T_e1a90_row3_col7, #T_e1a90_row4_col0, #T_e1a90_row4_col1, #T_e1a90_row4_col2, #T_e1a90_row4_col3, #T_e1a90_row4_col4, #T_e1a90_row4_col5, #T_e1a90_row4_col6, #T_e1a90_row4_col7, #T_e1a90_row5_col0, #T_e1a90_row5_col1, #T_e1a90_row5_col2, #T_e1a90_row5_col3, #T_e1a90_row5_col4, #T_e1a90_row5_col5, #T_e1a90_row5_col6, #T_e1a90_row5_col7, #T_e1a90_row6_col0, #T_e1a90_row6_col1, #T_e1a90_row6_col2, #T_e1a90_row6_col3, #T_e1a90_row6_col4, #T_e1a90_row6_col5, #T_e1a90_row6_col6, #T_e1a90_row6_col7, #T_e1a90_row7_col0, #T_e1a90_row7_col1, #T_e1a90_row7_col2, #T_e1a90_row7_col4, #T_e1a90_row7_col5, #T_e1a90_row7_col6, #T_e1a90_row7_col7, #T_e1a90_row8_col0, #T_e1a90_row8_col1, #T_e1a90_row8_col2, #T_e1a90_row8_col3, #T_e1a90_row8_col4, #T_e1a90_row8_col5, #T_e1a90_row8_col6, #T_e1a90_row8_col7, #T_e1a90_row9_col0, #T_e1a90_row9_col1, #T_e1a90_row9_col2, #T_e1a90_row9_col3, #T_e1a90_row9_col4, #T_e1a90_row9_col5, #T_e1a90_row9_col6, #T_e1a90_row9_col7, #T_e1a90_row10_col0, #T_e1a90_row10_col1, #T_e1a90_row10_col2, #T_e1a90_row10_col3, #T_e1a90_row10_col4, #T_e1a90_row10_col5, #T_e1a90_row10_col6, #T_e1a90_row10_col7, #T_e1a90_row11_col0, #T_e1a90_row11_col1, #T_e1a90_row11_col2, #T_e1a90_row11_col3, #T_e1a90_row11_col4, #T_e1a90_row11_col5, #T_e1a90_row11_col6, #T_e1a90_row11_col7, #T_e1a90_row12_col0, #T_e1a90_row12_col1, #T_e1a90_row12_col2, #T_e1a90_row12_col3, #T_e1a90_row12_col5, #T_e1a90_row12_col6, #T_e1a90_row12_col7, #T_e1a90_row13_col0, #T_e1a90_row13_col1, #T_e1a90_row13_col2, #T_e1a90_row13_col3, #T_e1a90_row13_col4, #T_e1a90_row13_col5, #T_e1a90_row13_col6, #T_e1a90_row13_col7 {
#   text-align: left;
# }
# #T_e1a90_row0_col1, #T_e1a90_row0_col5, #T_e1a90_row0_col6, #T_e1a90_row0_col7, #T_e1a90_row1_col2, #T_e1a90_row7_col3, #T_e1a90_row12_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e1a90_row0_col8, #T_e1a90_row1_col8, #T_e1a90_row2_col8, #T_e1a90_row3_col8, #T_e1a90_row4_col8, #T_e1a90_row5_col8, #T_e1a90_row6_col8, #T_e1a90_row8_col8, #T_e1a90_row9_col8, #T_e1a90_row10_col8, #T_e1a90_row11_col8, #T_e1a90_row12_col8, #T_e1a90_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e1a90_row7_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e1a90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1a90_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e1a90_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e1a90_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e1a90_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e1a90_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e1a90_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e1a90_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e1a90_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_e1a90_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1a90_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_e1a90_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_e1a90_row0_col1" class="data row0 col1" >0.8134</td>
#       <td id="T_e1a90_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_e1a90_row0_col3" class="data row0 col3" >0.9423</td>
#       <td id="T_e1a90_row0_col4" class="data row0 col4" >0.8419</td>
#       <td id="T_e1a90_row0_col5" class="data row0 col5" >0.8881</td>
#       <td id="T_e1a90_row0_col6" class="data row0 col6" >0.2988</td>
#       <td id="T_e1a90_row0_col7" class="data row0 col7" >0.3380</td>
#       <td id="T_e1a90_row0_col8" class="data row0 col8" >0.4250</td>
#     </tr>
#     <tr>
#       <th id="T_e1a90_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_e1a90_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_e1a90_row1_col1" class="data row1 col1" >0.8088</td>
#       <td id="T_e1a90_row1_col2" class="data row1 col2" >0.8088</td>
#       <td id="T_e1a90_row1_col3" class="data row1 col3" >0.9366</td>
#       <td id="T_e1a90_row1_col4" class="data row1 col4" >0.8410</td>
#       <td id="T_e1a90_row1_col5" class="data row1 col5" >0.8850</td>
#       <td id="T_e1a90_row1_col6" class="data row1 col6" >0.2889</td>
#       <td id="T_e1a90_row1_col7" class="data row1 col7" >0.3240</td>
#       <td id="T_e1a90_row1_col8" class="data row1 col8" >0.8138</td>
#     </tr>
#     <tr>
#       <th id="T_e1a90_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_e1a90_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_e1a90_row2_col1" class="data row2 col1" >0.8043</td>
#       <td id="T_e1a90_row2_col2" class="data row2 col2" >0.7912</td>
#       <td id="T_e1a90_row2_col3" class="data row2 col3" >0.9390</td>
#       <td id="T_e1a90_row2_col4" class="data row2 col4" >0.8354</td>
#       <td id="T_e1a90_row2_col5" class="data row2 col5" >0.8831</td>
#       <td id="T_e1a90_row2_col6" class="data row2 col6" >0.2630</td>
#       <td id="T_e1a90_row2_col7" class="data row2 col7" >0.2906</td>
#       <td id="T_e1a90_row2_col8" class="data row2 col8" >0.4350</td>
#     </tr>
#     <tr>
#       <th id="T_e1a90_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_e1a90_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_e1a90_row3_col1" class="data row3 col1" >0.7997</td>
#       <td id="T_e1a90_row3_col2" class="data row3 col2" >0.7330</td>
#       <td id="T_e1a90_row3_col3" class="data row3 col3" >0.9883</td>
#       <td id="T_e1a90_row3_col4" class="data row3 col4" >0.8043</td>
#       <td id="T_e1a90_row3_col5" class="data row3 col5" >0.8862</td>
#       <td id="T_e1a90_row3_col6" class="data row3 col6" >0.0531</td>
#       <td id="T_e1a90_row3_col7" class="data row3 col7" >0.0817</td>
#       <td id="T_e1a90_row3_col8" class="data row3 col8" >0.6362</td>
#     </tr>
#     <tr>
#       <th id="T_e1a90_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_e1a90_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e1a90_row4_col1" class="data row4 col1" >0.7997</td>
#       <td id="T_e1a90_row4_col2" class="data row4 col2" >0.7281</td>
#       <td id="T_e1a90_row4_col3" class="data row4 col3" >0.9775</td>
#       <td id="T_e1a90_row4_col4" class="data row4 col4" >0.8105</td>
#       <td id="T_e1a90_row4_col5" class="data row4 col5" >0.8853</td>
#       <td id="T_e1a90_row4_col6" class="data row4 col6" >0.0997</td>
#       <td id="T_e1a90_row4_col7" class="data row4 col7" >0.1432</td>
#       <td id="T_e1a90_row4_col8" class="data row4 col8" >0.3375</td>
#     </tr>
#     <tr>
#       <th id="T_e1a90_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_e1a90_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_e1a90_row5_col1" class="data row5 col1" >0.7996</td>
#       <td id="T_e1a90_row5_col2" class="data row5 col2" >0.6925</td>
#       <td id="T_e1a90_row5_col3" class="data row5 col3" >0.9514</td>
#       <td id="T_e1a90_row5_col4" class="data row5 col4" >0.8245</td>
#       <td id="T_e1a90_row5_col5" class="data row5 col5" >0.8823</td>
#       <td id="T_e1a90_row5_col6" class="data row5 col6" >0.2052</td>
#       <td id="T_e1a90_row5_col7" class="data row5 col7" >0.2374</td>
#       <
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, positive=False, random_state=42, solver='auto',
#                 tol=0.0001)

# %% [markdown]
# ## 使用gan生成的平衡数据

# %%
gan_data = pd.read_csv('gan_GSE25066.csv')

# %%
s2 = ClassificationExperiment()
s2.set_config('seed', 42)
s2.setup(gan_data, 
         target = 'group', 
         session_id = 42, 
         train_size=train_size, 
         fold_strategy='kfold',
         fold=fold,
        )
# Out:
# <style type="text/css">
# #T_ec3bf_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ec3bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec3bf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ec3bf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec3bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec3bf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ec3bf_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec3bf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ec3bf_row1_col1" class="data row1 col1" >group</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ec3bf_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ec3bf_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ec3bf_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ec3bf_row3_col1" class="data row3 col1" >(778, 13237)</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ec3bf_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ec3bf_row4_col1" class="data row4 col1" >(778, 13237)</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ec3bf_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ec3bf_row5_col1" class="data row5 col1" >(700, 13237)</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ec3bf_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ec3bf_row6_col1" class="data row6 col1" >(78, 13237)</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ec3bf_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ec3bf_row7_col1" class="data row7 col1" >13236</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ec3bf_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_ec3bf_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ec3bf_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_ec3bf_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ec3bf_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_ec3bf_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ec3bf_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_ec3bf_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ec3bf_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_ec3bf_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ec3bf_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_ec3bf_row13_col1" class="data row13 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ec3bf_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_ec3bf_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ec3bf_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_ec3bf_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ec3bf_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_ec3bf_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ec3bf_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_ec3bf_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ec3bf_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ec3bf_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_ec3bf_row18_col1" class="data row18 col1" >fce5</td>
#     </tr>
#   </tbody>
# </table>

# %%
s2.compare_models()
# Out:
# <style type="text/css">
# #T_95a7b th {
#   text-align: left;
# }
# #T_95a7b_row0_col0, #T_95a7b_row0_col2, #T_95a7b_row0_col3, #T_95a7b_row1_col0, #T_95a7b_row1_col1, #T_95a7b_row1_col2, #T_95a7b_row1_col3, #T_95a7b_row1_col4, #T_95a7b_row1_col5, #T_95a7b_row1_col6, #T_95a7b_row1_col7, #T_95a7b_row2_col0, #T_95a7b_row2_col1, #T_95a7b_row2_col3, #T_95a7b_row2_col4, #T_95a7b_row2_col5, #T_95a7b_row2_col6, #T_95a7b_row2_col7, #T_95a7b_row3_col0, #T_95a7b_row3_col1, #T_95a7b_row3_col2, #T_95a7b_row3_col3, #T_95a7b_row3_col4, #T_95a7b_row3_col5, #T_95a7b_row3_col6, #T_95a7b_row3_col7, #T_95a7b_row4_col0, #T_95a7b_row4_col1, #T_95a7b_row4_col2, #T_95a7b_row4_col4, #T_95a7b_row4_col5, #T_95a7b_row4_col6, #T_95a7b_row4_col7, #T_95a7b_row5_col0, #T_95a7b_row5_col1, #T_95a7b_row5_col2, #T_95a7b_row5_col3, #T_95a7b_row5_col4, #T_95a7b_row5_col5, #T_95a7b_row5_col6, #T_95a7b_row5_col7, #T_95a7b_row6_col0, #T_95a7b_row6_col1, #T_95a7b_row6_col2, #T_95a7b_row6_col3, #T_95a7b_row6_col4, #T_95a7b_row6_col5, #T_95a7b_row6_col6, #T_95a7b_row6_col7, #T_95a7b_row7_col0, #T_95a7b_row7_col1, #T_95a7b_row7_col2, #T_95a7b_row7_col3, #T_95a7b_row7_col4, #T_95a7b_row7_col5, #T_95a7b_row7_col6, #T_95a7b_row7_col7, #T_95a7b_row8_col0, #T_95a7b_row8_col1, #T_95a7b_row8_col2, #T_95a7b_row8_col3, #T_95a7b_row8_col4, #T_95a7b_row8_col5, #T_95a7b_row8_col6, #T_95a7b_row8_col7, #T_95a7b_row9_col0, #T_95a7b_row9_col1, #T_95a7b_row9_col2, #T_95a7b_row9_col3, #T_95a7b_row9_col4, #T_95a7b_row9_col5, #T_95a7b_row9_col6, #T_95a7b_row9_col7, #T_95a7b_row10_col0, #T_95a7b_row10_col1, #T_95a7b_row10_col2, #T_95a7b_row10_col3, #T_95a7b_row10_col4, #T_95a7b_row10_col5, #T_95a7b_row10_col6, #T_95a7b_row10_col7, #T_95a7b_row11_col0, #T_95a7b_row11_col1, #T_95a7b_row11_col2, #T_95a7b_row11_col3, #T_95a7b_row11_col4, #T_95a7b_row11_col5, #T_95a7b_row11_col6, #T_95a7b_row11_col7, #T_95a7b_row12_col0, #T_95a7b_row12_col1, #T_95a7b_row12_col2, #T_95a7b_row12_col3, #T_95a7b_row12_col4, #T_95a7b_row12_col5, #T_95a7b_row12_col6, #T_95a7b_row12_col7, #T_95a7b_row13_col0, #T_95a7b_row13_col1, #T_95a7b_row13_col2, #T_95a7b_row13_col3, #T_95a7b_row13_col4, #T_95a7b_row13_col5, #T_95a7b_row13_col6, #T_95a7b_row13_col7 {
#   text-align: left;
# }
# #T_95a7b_row0_col1, #T_95a7b_row0_col4, #T_95a7b_row0_col5, #T_95a7b_row0_col6, #T_95a7b_row0_col7, #T_95a7b_row2_col2, #T_95a7b_row4_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_95a7b_row0_col8, #T_95a7b_row1_col8, #T_95a7b_row2_col8, #T_95a7b_row3_col8, #T_95a7b_row4_col8, #T_95a7b_row5_col8, #T_95a7b_row6_col8, #T_95a7b_row8_col8, #T_95a7b_row9_col8, #T_95a7b_row10_col8, #T_95a7b_row11_col8, #T_95a7b_row12_col8, #T_95a7b_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_95a7b_row7_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_95a7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95a7b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_95a7b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_95a7b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_95a7b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_95a7b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_95a7b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_95a7b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_95a7b_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_95a7b_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95a7b_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_95a7b_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_95a7b_row0_col1" class="data row0 col1" >0.9272</td>
#       <td id="T_95a7b_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_95a7b_row0_col3" class="data row0 col3" >0.9197</td>
#       <td id="T_95a7b_row0_col4" class="data row0 col4" >0.9328</td>
#       <td id="T_95a7b_row0_col5" class="data row0 col5" >0.9254</td>
#       <td id="T_95a7b_row0_col6" class="data row0 col6" >0.8507</td>
#       <td id="T_95a7b_row0_col7" class="data row0 col7" >0.8526</td>
#       <td id="T_95a7b_row0_col8" class="data row0 col8" >0.3750</td>
#     </tr>
#     <tr>
#       <th id="T_95a7b_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_95a7b_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_95a7b_row1_col1" class="data row1 col1" >0.8743</td>
#       <td id="T_95a7b_row1_col2" class="data row1 col2" >0.9263</td>
#       <td id="T_95a7b_row1_col3" class="data row1 col3" >0.9925</td>
#       <td id="T_95a7b_row1_col4" class="data row1 col4" >0.8013</td>
#       <td id="T_95a7b_row1_col5" class="data row1 col5" >0.8856</td>
#       <td id="T_95a7b_row1_col6" class="data row1 col6" >0.7428</td>
#       <td id="T_95a7b_row1_col7" class="data row1 col7" >0.7660</td>
#       <td id="T_95a7b_row1_col8" class="data row1 col8" >0.5400</td>
#     </tr>
#     <tr>
#       <th id="T_95a7b_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_95a7b_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_95a7b_row2_col1" class="data row2 col1" >0.8729</td>
#       <td id="T_95a7b_row2_col2" class="data row2 col2" >0.9403</td>
#       <td id="T_95a7b_row2_col3" class="data row2 col3" >0.9313</td>
#       <td id="T_95a7b_row2_col4" class="data row2 col4" >0.8286</td>
#       <td id="T_95a7b_row2_col5" class="data row2 col5" >0.8765</td>
#       <td id="T_95a7b_row2_col6" class="data row2 col6" >0.7385</td>
#       <td id="T_95a7b_row2_col7" class="data row2 col7" >0.7454</td>
#       <td id="T_95a7b_row2_col8" class="data row2 col8" >0.4325</td>
#     </tr>
#     <tr>
#       <th id="T_95a7b_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_95a7b_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_95a7b_row3_col1" class="data row3 col1" >0.8714</td>
#       <td id="T_95a7b_row3_col2" class="data row3 col2" >0.9319</td>
#       <td id="T_95a7b_row3_col3" class="data row3 col3" >0.9972</td>
#       <td id="T_95a7b_row3_col4" class="data row3 col4" >0.7941</td>
#       <td id="T_95a7b_row3_col5" class="data row3 col5" >0.8834</td>
#       <td id="T_95a7b_row3_col6" class="data row3 col6" >0.7363</td>
#       <td id="T_95a7b_row3_col7" class="data row3 col7" >0.7626</td>
#       <td id="T_95a7b_row3_col8" class="data row3 col8" >0.4162</td>
#     </tr>
#     <tr>
#       <th id="T_95a7b_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_95a7b_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_95a7b_row4_col1" class="data row4 col1" >0.8700</td>
#       <td id="T_95a7b_row4_col2" class="data row4 col2" >0.8676</td>
#       <td id="T_95a7b_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_95a7b_row4_col4" class="data row4 col4" >0.7908</td>
#       <td id="T_95a7b_row4_col5" class="data row4 col5" >0.8823</td>
#       <td id="T_95a7b_row4_col6" class="data row4 col6" >0.7338</td>
#       <td id="T_95a7b_row4_col7" class="data row4 col7" >0.7618</td>
#       <td id="T_95a7b_row4_col8" class="data row4 col8" >0.4138</td>
#     </tr>
#     <tr>
#       <th id="T_95a7b_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_95a7b_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_95a7b_row5_col1" class="data row5 col1" >0.8686</td>
#       <td id="T_95a7b_row5_col2" class="data row5 col2" >0.9130</td>
#       <td id="T_95a7b_row5_col3" class="data row5 col3" >0.9495</td>
#       <td id="T_95a7b_row5_col4" class="data row5 col4" >0.8146</td>
#       <td id="T_95a7b_row5_col5" class="data row5 col5" >0.8762</td>
#       <td id="T_95a7b_row5_col6" class="data row5 col6" >0.7308</td>
#       <td id="T_95a7b_row5_col7" class="data row5 col7" >0.7416</td>
#       <td id="T_95a7b_row5_col8" class="
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, positive=False, random_state=42, solver='auto',
#                 tol=0.0001)

# %% [markdown]
# ## 读取pathways score

# %%
ptways_data = pd.read_csv('GSE25066_Pathways.csv')
ptways_data
# Out:
#            P1        P2        P3        P4        P5        P6        P7  \
# 0    0.652611  0.495346  0.047954  0.662963  0.735513  0.555973  0.378495
# 1    0.842995  0.037106  0.000000  0.626206  0.679602  0.169469  0.941549
# 2    0.408753  0.229237  0.258692  0.571939  0.337781  0.277547  0.259577
# 3    0.399076  0.296493  0.002233  0.878496  0.642641  0.485244  0.820809
# 4    0.619888  0.344163  0.145156  0.629054  0.792862  0.612424  0.645237
# ..        ...       ...       ...       ...       ...       ...       ...
# 773  0.780953  0.472283  0.402083  0.848834  0.841829  0.335453  0.816556
# 774  0.376542  0.664727  0.188929  0.467122  0.288284  0.247069  0.840098
# 775  0.383277  0.373971  0.360171  0.355983  0.295145  0.381857  0.260191
# 776  0.546009  0.306282  0.212256  0.686410  0.569083  0.040985  0.489773
# 777  0.438387  0.220758  0.237879  0.582270  0.523594  0.178777  0.877948
#
#            P8        P9       P10  ...      P287      P288      P289  \
# 0    0.541849  0.584928  0.649398  ...  0.609205  0.509882  0.623106
# 1    0.444544  0.000000  0.788208  ...  0.419986  0.517451  0.355912
# 2    0.304155  0.295918  0.354925  ...  0.346002  0.490969  0.371533
# 3    0.531869  0.467797  0.702102  ...  0.537548  0.542883  0.529179
# 4    0.636430  0.640469  0.425681  ...  0.584482  0.533999  0.633018
# ..        ...       ...       ...  ...       ...       ...       ...
# 773  0.250886  0.529502  0.699910  ...  0.458262  0.412346  0.328081
# 774  0.378218  0.441010  0.370800  ...  0.663944  0.380639  0.451076
# 775  0.185358  0.350350  0.417225  ...  0.372857  0.452868  0.373583
# 776  0.509462  0.235780  0.510976  ...  0.728129  0.388307  0.783554
# 777  0.427968  0.553783  0.540624  ...  0.418550  0.368652  0.445612
#
#          P290      P291      P292      P293      P294      P295  group
# 0    0.574223  0.496415  0.532876  0.722280  0.553822  0.608116      0
# 1    0.332875  0.257972  0.404462  0.743766  0.536958  0.104767      0
# 2    0.324349  0.282662  0.267778  0.586543  0.392367  0.330188      0
# 3    0.509160  0.372515  0.504179  0.602727  0.458319  0.477012      0
# 4    0.576897  0.570664  0.510094  0.766075  0.555534  0.622362      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 773  0.238987  0.345733  0.475420  0.578152  0.440174  0.335495      1
# 774  0.377037  0.242163  0.799175  0.436973  0.358878  0.381521      1
# 775  0.340856  0.348174  0.471055  0.583116  0.444745  0.367293      1
# 776  0.735152  0.128658  0.437308  0.232475  0.511149  0.796648      1
# 777  0.398496  0.249119  0.288598  0.584740  0.443402  0.449159      1
#
# [778 rows x 296 columns]

# %%
s3 = ClassificationExperiment()
s3.set_config('seed', 42)
s3.setup(ptways_data, 
         target = 'group', 
         session_id = 42, 
         train_size=train_size, 
         fold_strategy='kfold',
         fold=fold
        )
# Out:
# <style type="text/css">
# #T_86f27_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_86f27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86f27_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_86f27_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86f27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86f27_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_86f27_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86f27_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_86f27_row1_col1" class="data row1 col1" >group</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_86f27_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_86f27_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_86f27_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_86f27_row3_col1" class="data row3 col1" >(778, 296)</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_86f27_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_86f27_row4_col1" class="data row4 col1" >(778, 296)</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_86f27_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_86f27_row5_col1" class="data row5 col1" >(700, 296)</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_86f27_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_86f27_row6_col1" class="data row6 col1" >(78, 296)</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_86f27_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_86f27_row7_col1" class="data row7 col1" >295</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_86f27_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_86f27_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_86f27_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_86f27_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_86f27_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_86f27_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_86f27_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_86f27_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_86f27_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_86f27_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_86f27_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_86f27_row13_col1" class="data row13 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_86f27_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_86f27_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_86f27_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_86f27_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_86f27_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_86f27_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_86f27_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_86f27_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_86f27_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_86f27_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_86f27_row18_col1" class="data row18 col1" >c2c3</td>
#     </tr>
#   </tbody>
# </table>

# %%
s3.compare_models(cross_validation=False)
# Out:
# <style type="text/css">
# #T_854b1 th {
#   text-align: left;
# }
# #T_854b1_row0_col0, #T_854b1_row0_col2, #T_854b1_row0_col3, #T_854b1_row1_col0, #T_854b1_row1_col3, #T_854b1_row2_col0, #T_854b1_row2_col2, #T_854b1_row2_col3, #T_854b1_row3_col0, #T_854b1_row3_col1, #T_854b1_row3_col2, #T_854b1_row3_col3, #T_854b1_row3_col4, #T_854b1_row3_col5, #T_854b1_row3_col6, #T_854b1_row3_col7, #T_854b1_row4_col0, #T_854b1_row4_col1, #T_854b1_row4_col2, #T_854b1_row4_col3, #T_854b1_row4_col4, #T_854b1_row4_col5, #T_854b1_row4_col6, #T_854b1_row4_col7, #T_854b1_row5_col0, #T_854b1_row5_col1, #T_854b1_row5_col2, #T_854b1_row5_col3, #T_854b1_row5_col4, #T_854b1_row5_col5, #T_854b1_row5_col6, #T_854b1_row5_col7, #T_854b1_row6_col0, #T_854b1_row6_col1, #T_854b1_row6_col2, #T_854b1_row6_col3, #T_854b1_row6_col4, #T_854b1_row6_col5, #T_854b1_row6_col6, #T_854b1_row6_col7, #T_854b1_row7_col0, #T_854b1_row7_col1, #T_854b1_row7_col2, #T_854b1_row7_col3, #T_854b1_row7_col4, #T_854b1_row7_col5, #T_854b1_row7_col6, #T_854b1_row7_col7, #T_854b1_row8_col0, #T_854b1_row8_col1, #T_854b1_row8_col2, #T_854b1_row8_col3, #T_854b1_row8_col4, #T_854b1_row8_col5, #T_854b1_row8_col6, #T_854b1_row8_col7, #T_854b1_row9_col0, #T_854b1_row9_col1, #T_854b1_row9_col2, #T_854b1_row9_col3, #T_854b1_row9_col4, #T_854b1_row9_col5, #T_854b1_row9_col6, #T_854b1_row9_col7, #T_854b1_row10_col0, #T_854b1_row10_col1, #T_854b1_row10_col2, #T_854b1_row10_col3, #T_854b1_row10_col4, #T_854b1_row10_col5, #T_854b1_row10_col6, #T_854b1_row10_col7, #T_854b1_row11_col0, #T_854b1_row11_col1, #T_854b1_row11_col2, #T_854b1_row11_col4, #T_854b1_row11_col5, #T_854b1_row11_col6, #T_854b1_row11_col7, #T_854b1_row12_col0, #T_854b1_row12_col1, #T_854b1_row12_col2, #T_854b1_row12_col3, #T_854b1_row12_col4, #T_854b1_row12_col5, #T_854b1_row12_col6, #T_854b1_row12_col7, #T_854b1_row13_col0, #T_854b1_row13_col1, #T_854b1_row13_col2, #T_854b1_row13_col3, #T_854b1_row13_col4, #T_854b1_row13_col5, #T_854b1_row13_col6, #T_854b1_row13_col7 {
#   text-align: left;
# }
# #T_854b1_row0_col1, #T_854b1_row0_col4, #T_854b1_row0_col5, #T_854b1_row0_col6, #T_854b1_row0_col7, #T_854b1_row1_col1, #T_854b1_row1_col2, #T_854b1_row1_col4, #T_854b1_row1_col5, #T_854b1_row1_col6, #T_854b1_row1_col7, #T_854b1_row2_col1, #T_854b1_row2_col4, #T_854b1_row2_col5, #T_854b1_row2_col6, #T_854b1_row2_col7, #T_854b1_row11_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_854b1_row0_col8, #T_854b1_row1_col8, #T_854b1_row2_col8, #T_854b1_row3_col8, #T_854b1_row4_col8, #T_854b1_row6_col8, #T_854b1_row7_col8, #T_854b1_row8_col8, #T_854b1_row9_col8, #T_854b1_row11_col8, #T_854b1_row12_col8, #T_854b1_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_854b1_row5_col8, #T_854b1_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_854b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_854b1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_854b1_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_854b1_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_854b1_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_854b1_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_854b1_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_854b1_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_854b1_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_854b1_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_854b1_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_854b1_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_854b1_row0_col1" class="data row0 col1" >0.9744</td>
#       <td id="T_854b1_row0_col2" class="data row0 col2" >0.9980</td>
#       <td id="T_854b1_row0_col3" class="data row0 col3" >0.9487</td>
#       <td id="T_854b1_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_854b1_row0_col5" class="data row0 col5" >0.9737</td>
#       <td id="T_854b1_row0_col6" class="data row0 col6" >0.9487</td>
#       <td id="T_854b1_row0_col7" class="data row0 col7" >0.9500</td>
#       <td id="T_854b1_row0_col8" class="data row0 col8" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_854b1_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_854b1_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_854b1_row1_col1" class="data row1 col1" >0.9744</td>
#       <td id="T_854b1_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_854b1_row1_col3" class="data row1 col3" >0.9487</td>
#       <td id="T_854b1_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_854b1_row1_col5" class="data row1 col5" >0.9737</td>
#       <td id="T_854b1_row1_col6" class="data row1 col6" >0.9487</td>
#       <td id="T_854b1_row1_col7" class="data row1 col7" >0.9500</td>
#       <td id="T_854b1_row1_col8" class="data row1 col8" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_854b1_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_854b1_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_854b1_row2_col1" class="data row2 col1" >0.9744</td>
#       <td id="T_854b1_row2_col2" class="data row2 col2" >0.9934</td>
#       <td id="T_854b1_row2_col3" class="data row2 col3" >0.9487</td>
#       <td id="T_854b1_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_854b1_row2_col5" class="data row2 col5" >0.9737</td>
#       <td id="T_854b1_row2_col6" class="data row2 col6" >0.9487</td>
#       <td id="T_854b1_row2_col7" class="data row2 col7" >0.9500</td>
#       <td id="T_854b1_row2_col8" class="data row2 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_854b1_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_854b1_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_854b1_row3_col1" class="data row3 col1" >0.9615</td>
#       <td id="T_854b1_row3_col2" class="data row3 col2" >0.9961</td>
#       <td id="T_854b1_row3_col3" class="data row3 col3" >0.9744</td>
#       <td id="T_854b1_row3_col4" class="data row3 col4" >0.9500</td>
#       <td id="T_854b1_row3_col5" class="data row3 col5" >0.9620</td>
#       <td id="T_854b1_row3_col6" class="data row3 col6" >0.9231</td>
#       <td id="T_854b1_row3_col7" class="data row3 col7" >0.9234</td>
#       <td id="T_854b1_row3_col8" class="data row3 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_854b1_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_854b1_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_854b1_row4_col1" class="data row4 col1" >0.8974</td>
#       <td id="T_854b1_row4_col2" class="data row4 col2" >0.8974</td>
#       <td id="T_854b1_row4_col3" class="data row4 col3" >0.8974</td>
#       <td id="T_854b1_row4_col4" class="data row4 col4" >0.8974</td>
#       <td id="T_854b1_row4_col5" class="data row4 col5" >0.8974</td>
#       <td id="T_854b1_row4_col6" class="data row4 col6" >0.7949</td>
#       <td id="T_854b1_row4_col7" class="data row4 col7" >0.7949</td>
#       <td id="T_854b1_row4_col8" class="data row4 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_854b1_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_854b1_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_854b1_row5_col1" class="data row5 col1" >0.8846</td>
#       <td id="T_854b1_row5_col2" class="data row5 col2" >0.9707</td>
#       <td id="T_854b1_row5_col3" class="data row5 col3" >0.7949</td>
#       <td id="T_854b1_row5_col4" class="data row5 col4" >0.9688</td>
#       <td id="T_854b1_row5_col5" class="data row5 col5" >0.8732</td>
#       <td id="T_854b1_row5_col6" class="data row5 col6" >0.7692</td>
#       <td id="T_854b1_row5_col7" class="data row5 col7" >0.7819</td>
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=42, verbose=0, warm_start=False)
